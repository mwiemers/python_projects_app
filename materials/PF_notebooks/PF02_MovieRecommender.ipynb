# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: #f2f2f2; color:#3F3F3F; width:90%; padding:50px; -webkit-border-radius:5px">
#
# ## Python Fundamentals 2: Movie Recommender
#
# In this project you create a movie recommender that selects movies based on the user's preferences from a large dataset listing several thousand movies.
#
# You will be given a series of tasks to complete, guiding you through the steps of building the movie recommender.
#
# To solve these tasks, you will use the same resources that coders around the world rely on when they don’t know how to do something – online resources/tools, colleagues, and trial and error.
#
# We will use Jupyter notebooks for this task, which will allow you to write and test your code section by section.
#
# <b>After having completed this session, you will be able to:</b>
# * use lists to save multiple values in a single variable
# * select single values and ranges of values from a list
# * use nested lists to represent multi-dimensional data
# * use for loops to sequentially select elements from a list
# * use for loops to sequentially select lists from a nested list
# * combine for loops and if statements to filter out elements from a list
# * combine string values from a list into a single string for printing
#
# <b>What to do when getting stuck</b>:
#     <ol>
#         <li><b>Search online</b>: Being able to search for relevant information online by formulating your problem as an effective search term is a highly important skill for programmers at all levels of proficiency. We recommend the following approach to searching online for help:</li>
#         <ol>
#             <li>Start looking for help on <a href="https://www.w3schools.com">w3schools.com</a>. This website has tutorials on most fundamental Python concepts and features a coding section to try out new code.</li>
#             <li>If you cannot find help on w3schools, search on <a href="https://www.google.com">google.com</a>. Although you will often find references to stackoverflow, we recommend to look for alternative websites, as posts on stackoverflow are usually not written in a beginner-friendly way.</li>
#         </ol>
#         <li>Check with the people sitting around you. In a real job, you would seek help from your colleagues and friends, so start that now. If you don’t know the person next to you, introduce yourself now. </li>
#         <li>Ask the <b>trainer</b> if you struggle to find a solution.</li>
#     </ol>
#
#
# ### Earn your Python certificate
#
# The Python Fundamentals series consists of 5 different projects that each teach a different topic. After having completed the series you can claim an online certificate to provide evidence of your Python skills on e.g. LinkdedIN. Please email digital.skills.lab@lse.ac.uk to claim your certificate.
#
# There are two types of certificates you can claim.
#
# * <b>Python Fundamentals Attendance Badge</b>: For learners that have completed all Python projects apart from the coding challenges notebook. This certificate provides evidence of you having completed all exercises apart from the coding challenge.
# * <b>Python Fundamentals Knowledge Badge</b>: For learners that have completed the coding challenges. This certificate provides evidence of having successfully applied the fundamental Python skills to a more complex coding project. This is to highlight that in order to solve the final coding challenges a deeper understanding of the acquired coding techniques and advanced proficiency in their practical application are required.
#
# <img src="https://www.dropbox.com/scl/fi/1pbkoqos3u9taqmvdkmqc/pf_badge2.png?rlkey=tuy2ocn81fdvmip3thiqxwqdj&st=3nwupg3f&raw=1" height="250px">

# %% [markdown]
# <img src="https://www.dropbox.com/scl/fi/t67sowz9hkxfnmshvk1pe/recommender_tv.png?rlkey=sqbpw9s510lqv0zqkt5ocdjfx&st=n9n8qyhm&raw=1" width=1000>

# %% [markdown]
# You've always been a movie enthusiast, and now that you and your friends have more free time, you want to make the most of your movie nights. However, with everyone's different tastes and the vast number of movies available, deciding on a film can be quite challenging. Inspired by your newly developed Python skills, you decide to create a script that simplifies movie selection, ensuring everyone can enjoy the perfect movie together.

# %% [markdown]
# Your code should allow the user to:
#
# * Enter a few information on their movie preferences
# * Output a number of recommendations that take account of the user's preferences

# %% [markdown]
# ### Example of what the final output could look like
#
# See below for example of finished output

# %% [markdown]
# User entering values
#
#
# <iframe src="https://www.loom.com/embed/c715eee4ba344eaf94c3f4370a9a04c2?sid=32c9602d-eb8c-4fe1-8d31-fd9c62961bd5" width="800" height="600" frameborder="0" webkitallowfullscreen mozallowfullscreen allowfullscreen></iframe>

# %% [markdown]
# Final output
#
# <img src="https://www.dropbox.com/scl/fi/34tti4peil81lptqhnlz6/movie_recommender_01.png?rlkey=5494cjai2k0tdil77o5tnl8xp&st=h6lou1w4&raw=1" width=600>

# %% [markdown]
# ## A Simple Movie Recommendation System
#
# We recommend to break down the problem into the following smaller tasks.
#
#
# 1. Store the following items in a single variable named `movies`.
#     - Catfish
#     - Backdraft
#     - Homegrown
#     - Brother 2 (Brat 2)
#     - Fat Albert
#     - Trash Humpers
#     - Jim Gaffigan: Cinco
#     - American Gigolo
#     - Stagecoach
#     - The Eagle Has Landed
#
#
# 2. In order to recommend a random movie, shuffle the elements of the `movies` variable and access the first movie.
#
# 3. Shuffle the movies in the `movies` variable. After shuffling the movies, access the first 5 movies from `movies` and store these in the variable `random_movies`. Print the randomly selected movies.
#
# 4. Adjust your code from task 3 to cycle through each movie from `movies` one at a time and print each movie in a separate line.
#
# 5. Store the following movies in a single variable named `movies`. You can still use the same data type as you used in task 1-4, but it needs to be the nested version of that datatype. Each element of the variable `movies` should represent a movie and store multiple values corresponding to the name, year, genre, and rating.
#
#     - 'Wolf Children (Okami kodomo no ame to yuki)', '2012', 'Animation', '4.0'
#     - 'LBJ', '2017', 'Drama', '4.0'
#     - 'Ring of Terror', '1962', 'Horror', '0.5'
#     - 'Christine', '1983', 'Horror', '2.95'
#     - 'Prime Suspect: The Lost Child', '1995', 'Drama', '2.0'
#     - "Hard Day's Night, A", '1964', 'Adventure', '3.473684210526316'
#     - 'Two Jakes, The', '1990', 'Drama', '1.25'
#     - 'Red Badge of Courage, The', '1951', 'Drama', '4.0'
#     - 'Dragon Ball Z the Movie: The Tree of Might (Doragon bôru Z 3: Chikyû marugoto chô kessen)', '1990', 'Action', '3.0'
#     - 'When a Man Loves a Woman', '1994', 'Drama', '3.8181818181818183'
#
# 6. As in task 4, display the first 5 movies after shuffling the movies. Print each movie in a new line.
#
# 7. Adjust your code from task 6, to only print the name of the movie instead of all information. Print each movie name in a new line.
#
# 8. Ask the user to enter a minimum average rating. Only recommend movies if their average rating is above the entered minimum. If you struggle with this, we recommend to do this for only one movie initially before doing it by cycling through all movies.
#
# 9. Ask also about the genre and the oldest year of release and only print movies that meet these criteria.
#
# 10. Update your code so that in the first step, you load the ml_all_small.csv file as a list of lists into Python. Use this data to provide movie recommendations instead of the shorter list of movies that you previously created manually.
#
# 11. Adjust your code to take account of different ways users might enter the value for the genre. Ensure that your code can handle user inputs that may have different cases (upper or lowercase letters) and extra spaces at the beginning or end of the genre values. If you struggle with this, we recommend to try out the effect of the adjustments one by one before adding this to your movie recommender code.
#
# 12. Depending on the user criteria, your code might return a very large number of movies. Also ask the user about the maximum number of movies to recommend and ensure the recommender only prints at maximum as many movies as defined by the user.
#
# 13. To improve the output of your movie recommender, combine the different values from each movie with a hyphen so that the movie is printed as Lincoln - 2012 - Drama - 4.5 instead of ['Lincoln', '2012', 'Drama', '4.5'].

# %% [markdown]
# ---

# %% [markdown]
# ##### 1 - Storing movies
#
# Store the following items in a single variable named `movies`.
#
# Catfish, Backdraft, Homegrown, Brother 2 (Brat 2), Fat Albert, Trash Humpers, Jim Gaffigan: Cinco, American Gigolo, Stagecoach, The Eagle Has Landed

# %%
# Catfish, Backdraft, Homegrown, Brother 2 (Brat 2), Fat Albert, Trash Humpers, Jim Gaffigan: Cinco, American Gigolo, Stagecoach, The Eagle Has Landed

# %% [markdown]
# ---
#
# ##### 2 - Shuffling movies
#
# Shuffle the elements from `movies` and access the first movie.

# %% [markdown]
# ---
#
# ##### 3 - Accessing movies
#
# Shuffle the movies in the `movies` collection.
#
# After shuffling the movies, access the first 5 movies from `movies` and store these in the variable `random_movies`.
#
# Print the randomly selected movies.

# %% [markdown]
# ---
#
# ##### 4 - Printing each movie in a separate line
#
# Adjust your code from task 3 to cycle through each movie from `movies` one at a time and print each movie in a separate line.

# %% [markdown]
# ---
#
# ##### 5 - Store movies as nested data type
#
# Store the following movies in a single variable named `movies`.
#
# You can still use the same data type as you used in task 1-4, but it needs to be the nested version of that datatype.
#
# Each element of the variable `movies` should represent a movie and store multiple values corresponding to the name, year, genre, rating.

# %%
# - 'Wolf Children (Okami kodomo no ame to yuki)', '2012', 'Animation', '4.0'
# - 'LBJ', '2017', 'Drama', '4.0'
# - 'Ring of Terror', '1962', 'Horror', '0.5'
# - 'Christine', '1983', 'Horror', '2.95'
# - 'Prime Suspect: The Lost Child', '1995', 'Drama', '2.0'
# - "Hard Day's Night, A", '1964', 'Adventure', '3.473684210526316'
# - 'Two Jakes, The', '1990', 'Drama', '1.25'
# - 'Red Badge of Courage, The', '1951', 'Drama', '4.0'
# - 'Dragon Ball Z the Movie: The Tree of Might (Doragon bôru Z 3: Chikyû marugoto chô kessen)', '1990', 'Action', '3.0'
# - 'When a Man Loves a Woman', '1994', 'Drama', '3.8181818181818183'

# %% [markdown]
# ---
#
# ##### 6 - Print movies in separate lines
#
# As in task 4, display the first 5 movies after shuffling the movies. Print each movie in a new line.

# %% [markdown]
# ---
#
# ##### 7 - Print movie names instead of entire movie info
#
# Adjust your code from task 6, to only print the name of the movie instead of all information. Print each movie name in a new line.

# %% [markdown]
# ---
#
# ##### 8 - Only print movies that meet condition
#
# Ask the user to enter a minimum average rating. Only recommend movies if they meet the condition that the average rating is above the minimum value provided by the user.
#
# If you struggle with this, we recommend to do this for only one movie initially before doing it by cycling through all movies.

# %% [markdown]
# ---
#
# ##### 9 - Add more conditions for recommending a movie
#
# Ask also about the genre and the oldest year of release and only print movies that meet the conditions of having the same genre and a year value that is at least as large as the value provided by the user.
#
# If you struggle with this, you might find it easier to test your conditions on a single movie first.

# %% [markdown]
# ---
#
# ##### 10 - Using the ml_small.csv file to make recommendations
#
# Update your code so that in the first step, you load the ml_all_small.csv file as the correct data type into Python.
#
# Use this data to provide movie recommendations instead of the shorter list of movies that you previously created man

# %% [markdown]
# ---
#
# ##### 11 - Input normalisation
#
# Adjust your code to take account of different ways users might enter genre values.
#
# Ensure that your code can handle user inputs that may have different cases (upper or lowercase letters) and extra spaces at the beginning or end of the genre values.
#
# If you struggle with this, we recommend to try out the effect of the adjustments one by one before adding this to your movie recommender code.

# %% [markdown]
# ---
#
# ##### 12 - Limiting the number of recommended movies to a number defined by the user
#
# Depending on the user criteria, your code might return a very large number of movies.
#
# Ask the user about the maximum number of movies to recommend and ensure the recommender only prints at maximum as many movies as defined by the user.
#
# Be aware that you cannot first select a subset of movies from all movies and then print only those that meet the other critera (rating, genre, year). You need to find a way to keep track of how many movies have already been recommended so far.

# %% [markdown]
# ---
#
# ##### 13 - Formatting the output
#
# To improve the output of your movie recommender, combine the different values from each movie with a hyphen so that the movie is printed as
#
# Lincoln - 2012 - Drama - 4.5
#
# instead of
#
# ['Lincoln', '2012', 'Drama', '4.5']

# %% [markdown]
# ---
#
# ##### 14 - Adding a summary of the search criteria
#
# Add a short summary about the search criteria before you print the movie recommendations

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color:#ECECEB; color:#3F3F3F; width:90%; padding:50px; -webkit-border-radius:5px">
#
# ### Final task: Please give us your feedback!
#
# Upon completing the survey, **you will receive the link to the solution file**, to check how your code compares to the sample solution.
#
# In order to adapt our training to your needs and provide the most valuable learning experience for you, we depend on your feedack.
#
# We would be grateful if you could take **1 min** before the end of the workshop to get your feedback!
#
# <a href="https://lse.eu.qualtrics.com/jfe/form/SV_e4gllqd7FvmCNzo?coursename=Python Projects 2: Movie Recommender&topic=Python&link=https://lsecloud-my.sharepoint.com/:u:/g/personal/m_wiemers_lse_ac_uk/EfFVOdGAt1pMr7Xpx3PBMH8B7Pq_p9AOg5RKCsj159lllw?e=3eVhHH&prog=DS&version=24-25"><b>Click here to open the survey!</b></a>
#
#
#
# </div>
