# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: #f2f2f2; color:#3F3F3F; width:90%; padding:50px; -webkit-border-radius:5px">
#
# ## Python Fundamentals 4: SoundFree App
#
# In this project you create a simple music app that can play, pause and skip songs.
#
# You will be given a series of tasks to complete, guiding you through the steps of building the app.
#
# To solve these tasks, you will use the same resources that coders around the world rely on when they don’t know how to do something – online resources/tools, colleagues, and trial and error.
#
# We will use Jupyter notebooks for this task, which will allow you to write and test your code section by section.
#
# <b>After having completed this session, you will be able to:</b>
# * write functions to create reusable code that can be called with a name.
# * use while loops to repeat a section of code until a specific condition is no longer true.
# * write more complex/nested if-else constructs
# * use the pygame library to play music
# * use the keyboard module to handle keyboard presses
#
# <b>What to do when getting stuck</b>:
#     <ol>
#         <li><b>Search online</b>: Being able to search for relevant information online by formulating your problem as an effective search term is a highly important skill for programmers at all levels of proficiency. We recommend the following approach to searching online for help:</li>
#         <ol>
#             <li>Start looking for help on <a href="https://www.w3schools.com">w3schools.com</a>. This website has tutorials on most fundamental Python concepts and features a coding section to try out new code.</li>
#             <li>If you cannot find help on w3schools, search on <a href="https://www.google.com">google.com</a>. Although you will often find references to stackoverflow, we recommend to look for alternative websites, as posts on stackoverflow are usually not written in a beginner-friendly way.</li>
#         </ol>
#         <li>Check with the people sitting around you. In a real job, you would seek help from your colleagues and friends, so start that now. If you don’t know the person next to you, introduce yourself now. </li>
#         <li>Ask the <b>trainer</b> if you struggle to find a solution.</li>
#     </ol>
#
#
# ### Earn your Python certificate
#
# The Python Fundamentals series consists of 5 different projects that each teach a different topic. After having completed the series you can claim an online certificate to provide evidence of your Python skills on e.g. LinkdedIN. Please email digital.skills.lab@lse.ac.uk to claim your certificate.
#
# There are two types of certificates you can claim.
#
# * <b>Python Fundamentals Attendance Badge</b>: For learners that have completed all Python projects apart from the coding challenges notebook. This certificate provides evidence of you having completed all exercises apart from the coding challenge.
# * <b>Python Fundamentals Knowledge Badge</b>: For learners that have completed the coding challenges. This certificate provides evidence of having successfully applied the fundamental Python skills to a more complex coding project. This is to highlight that in order to solve the final coding challenges a deeper understanding of the acquired coding techniques and advanced proficiency in their practical application are required.
#
# <img src="https://www.dropbox.com/scl/fi/1pbkoqos3u9taqmvdkmqc/pf_badge2.png?rlkey=tuy2ocn81fdvmip3thiqxwqdj&st=3nwupg3f&raw=1" height="250px">

# %% [markdown]
# <img src="https://www.dropbox.com/scl/fi/ix3kk1bxeqghx8jb0z5sm/soundfree.webp?rlkey=ir10r7mfeau4ktcqaw7fa6srq&st=3hn989zz&raw=1" height=500>

# %% [markdown]
# Now that the song data has been cleaned, you can move on to writing the first version of a prototype of the SoundFree app.

# %% [markdown]
# Here are the criteria for the app:
#
# * Load the song info data into Python.
# * Play mp3 files corresponding to the information listed in the song info data.
# * Display the artist, title and playing time of the current song.
# * Provide a simple user interface in the console so that users can:
#     - Skip to the next/previous song.
#     - Pause/unpause a song.
#     - Quit the app.

# %% [markdown]
# ### Example of what the final output could look like
#
# See below for example of finished output
#
# <video width="600" height="400" controls>
#   <source src="https://www.dropbox.com/scl/fi/r6wnfid9ul34ikrn40431/soundfree_demo.mp4?rlkey=eg95k5iaadjtip59g295j6mvu&st=ak416cjh&raw=1" type="video/mp4">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# Video tutorial in using scripts in VS Code

# %% [markdown]
# Video tutorial on best setup for this task
# - Split screen, jupyter notebook left, PY scripts on the right split screen

# %% [markdown]
# ## SoundFree App
#
#
# For this task, we recommend to use Python scripts instead of jupyter notebooks.
#
# See here for a short introduction to how to work effectively with Python scripts in VS Code.
#
# We recommend to break down the problem into the following smaller tasks. It might be easiest to create a new script for each task.
#
# 1. Load the `song_info_clean.csv` file from song_info folder. Split the song info into `song_fields` for the headers and `song_info` for the actual song info data.
#
# 2. Download the mp3s from the [following link](https://lsecloud-my.sharepoint.com/:f:/g/personal/m_wiemers_lse_ac_uk/Ev_YYTjhbF5PhDHvaevkUl4BLDKjoe4qnx47d-8y-KHeMw?e=Snv8sD) and store them in a folder named `songs` inside the same folder where you keep this jupyter notebook and your python script(s) for this project.
#
# 3. Use pygame to load and play the mp3 corresponding to the first song. The format of the mp3 file names is "[Track title] - [Artist].mp3".
#
# 4. Adjust your code to make Python wait for 5 seconds after playing a song and then stop the song.
#
# 5. Write a reusable piece of code that will play the first song for 5 seconds. Use the name `play_1st_song` for this piece of code. Test whether you can play the first song for 5 seconds, using the `play_1st_song` code. You will need to work through an online tutorial to understand the basics of writing reusable code in Python before attempting to solve this task.
#
# 6. Rename the `play_1st_song` piece of code to `play_song`. This updated reusable code should take the information from *a specific song* as input. The `play_song` code should then load the song corresponding to the song information and play the mp3 for 5 seconds. Test that `play_song` works for different songs.
#
# 7. Your colleague Adrian wrote a first version of the main app loop. This code is supposed to play through all songs once. Run his code and observe what it does. You will need to work through an online tutorial to understand any new commands in  Adrian's code before attempting to solve this task.
#     1. Adjust the code so that it plays the next song every 5 seconds.
#     2. Adjust the code so that it doesn't wait 5 seconds to play the next song, but instead ask the user when to play the next song by pressing the d key.
#     3. Adjust the code so that the main app loop stops when the user decides to press the q key.
#     4. Adjust the code so that the music stops playing after the main app loop has stopped.
#     5. Adjust the code so that the app plays the first song when the user decides to play the song after the last one in the list.
#     6. Adjust the code so that the app displays the artist and title of the song currently playing and the options (d for next song and q to quit). Every time the user enters d to play the next song, the app should clear the terminal to remove the currently printed text and then print the updated information to show the currently playing song and the options.
#
# ```python
#     i = 0
#     while i < len(song_info):
#         play_song(song_info[i])
# ```
#
# 8. It's time to improve the user experience. The input function stops the flow of the app as it waits for the user to hit the enter key. If the user does not enter a value, the app will keep waiting for input and not go on to play the next song when the current one has finished. To provide a more seamless experience, we can use the keyboard module to get user input.
#
#     1. Adjust your code to use the keyboard module to check whether the user is currently pressing the q or d key. Only play the next song, when the user has pressed the d key!
#     2. When the user keeps holding down the d key, the app will keep skipping songs. Find a way to only skip to the next song when the user is *pressing down* the key. To skip again, the user first has to release the d key and then press it down again.
#     3. Verify that your code performs as desired:
#         - The app skips to the next song when the user presses d.
#         - The app quits when the user presses q.
#         - The app plays the next song when the current song has finished.
#     4. Add an option to play the previous song. Also take into account that the user might skip backwards to the previous song when the app is playing the first song in the list.
#     5. Add another option to pause/unpause the song.
#     6. Update the information that is being displayed to include the go back and pause/unpause options.

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color:#ECECEB; color:#3F3F3F; width:90%; padding:50px; -webkit-border-radius:5px">
#
# ### Final task: Please give us your feedback!
#
# Upon completing the survey, **you will receive the link to the solution file**, to check how your code compares to the sample solution.
#
# In order to adapt our training to your needs and provide the most valuable learning experience for you, we depend on your feedack.
#
# We would be grateful if you could take **1 min** before the end of the workshop to get your feedback!
#
# <a href="https://lse.eu.qualtrics.com/jfe/form/SV_e4gllqd7FvmCNzo?coursename=Python Projects 2: Movie Recommender&topic=Python&link=https://lsecloud-my.sharepoint.com/:u:/g/personal/m_wiemers_lse_ac_uk/EZQkJlAcKI1AgU4JFRxi2BgBVdyEGajn0rufHoJqnZ_5tw?e=CbT1WH&prog=DS&version=24-25"><b>Click here to open the survey!</b></a>
#
#
#
# </div>
